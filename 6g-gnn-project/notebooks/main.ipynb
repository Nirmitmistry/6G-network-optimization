# %% [markdown]
# # 6G GNN-DRL — Full Pipeline
# Runs both training stages end-to-end:
# 1. Pre-train the GNN encoder
# 2. Train the DQN agent with GNN-encoded states
#
# You can also run each stage independently via `train_gnn.ipynb` and `train_rl.ipynb`.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

# %% [markdown]
# ## Step 1 — Pre-train GNN Encoder

# %%
from training.train_gnn import train as train_gnn

print('=== GNN Pre-Training ===')
train_gnn(config_path='../configs/config.yaml')
# Out:
# === GNN Pre-Training ===
# Epoch 001 | Loss: 0.3128
# Epoch 002 | Loss: 0.1258
# Epoch 003 | Loss: 0.1059
# Epoch 004 | Loss: 0.0928
# Epoch 005 | Loss: 0.0915
# Epoch 006 | Loss: 0.0898
# Epoch 007 | Loss: 0.0895
# Epoch 008 | Loss: 0.0886
# Epoch 009 | Loss: 0.0883
# Epoch 010 | Loss: 0.0872
# Epoch 011 | Loss: 0.0876
# Epoch 012 | Loss: 0.0873
# Epoch 013 | Loss: 0.0867
# Epoch 014 | Loss: 0.0859
# Epoch 015 | Loss: 0.0868
# Epoch 016 | Loss: 0.0868
# Epoch 017 | Loss: 0.0863
# Epoch 018 | Loss: 0.0850
# Epoch 019 | Loss: 0.0865
# Epoch 020 | Loss: 0.0859
# Epoch 021 | Loss: 0.0858
# Epoch 022 | Loss: 0.0863
# Epoch 023 | Loss: 0.0862
# Epoch 024 | Loss: 0.0855
# Epoch 025 | Loss: 0.0857
# Epoch 026 | Loss: 0.0853
# Epoch 027 | Loss: 0.0855
# Epoch 028 | Loss: 0.0854
# Epoch 029 | Loss: 0.0850
# Epoch 030 | Loss: 0.0851
# Epoch 031 | Loss: 0.0850
# Epoch 032 | Loss: 0.0843
# Epoch 033 | Loss: 0.0851
# Epoch 034 | Loss: 0.0854
# Epoch 035 | Loss: 0.0855
# Epoch 036 | Loss: 0.0852
# Epoch 037 | Loss: 0.0849
# Epoch 038 | Loss: 0.0852
# Epoch 039 | Loss: 0.0847
# Epoch 040 | Loss: 0.0851
# Epoch 041 | Loss: 0.0852
# Epoch 042 | Loss: 0.0859
# Epoch 043 | Loss: 0.0853
# Epoch 044 | Loss: 0.0850
# Epoch 045 | Loss: 0.0847
# Epoch 046 | Loss: 0.0852
# Epoch 047 | Loss: 0.0847
# Epoch 048 | Loss: 0.0841
# Epoch 049 | Loss: 0.0856
# Epoch 050 | Loss: 0.0848
# GNN saved to results/gnn_pretrained.pt

# %% [markdown]
# ## Step 2 — Train DQN Agent

# %%
from training.train_rl import train as train_rl

print('=== DQN RL Training ===')
train_rl(config_path='../configs/config.yaml')
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# === DQN RL Training ===
# Loaded pretrained GNN from results/gnn_pretrained.pt
# GNN state dim: 1342 | Actions: 300
# Episode 50/500 | Total Reward: 67.754 | ε: 0.050
# Episode 100/500 | Total Reward: 62.283 | ε: 0.050

# %%
print('All done. Check results/ for saved models and plots.')
